# %%
import pandas as pd

# %%
arquivo = pd.read_csv("C:\\Users\\thelo\\OneDrive\\Documentos\\faculdade\\Pesquisa\\IC\\Projeto\\UNSW-NB15 - CSV Files\\a part of training and testing set",low_memory=False)

# %%
arquivo.head()

# %%
#Muda o valor de setosa para 0 nas linhas, na coluna style // pra usar a sklearn os rotulos precisam ser em numeros
#nesse caso como so tem tres species de plantas, decidi colocar 0, 1 e 2
arquivo ['attack_cat'] = arquivo['attack_cat'].replace('Normal',0)
arquivo ['attack_cat'] = arquivo['attack_cat'].replace('Fuzzers',1)
arquivo ['attack_cat'] = arquivo['attack_cat'].replace('Analysis',2)
arquivo ['attack_cat'] = arquivo['attack_cat'].replace('Backdoors',3)
arquivo ['attack_cat'] = arquivo['attack_cat'].replace('DoS',4)
arquivo ['attack_cat'] = arquivo['attack_cat'].replace('Exploits',5)
arquivo ['attack_cat'] = arquivo['attack_cat'].replace('Generic',6)
arquivo ['attack_cat'] = arquivo['attack_cat'].replace('Reconnaissance',7)
arquivo ['attack_cat'] = arquivo['attack_cat'].replace('Shellcode',8)
arquivo ['attack_cat'] = arquivo['attack_cat'].replace('Worms',9)

# %%
i =0
for x in arquivo["state"].unique():
    arquivo ['state'] = arquivo['state'].replace(x,i)
    i = i +1

# %%
i =0
for x in arquivo["service"].unique():
    arquivo ['service'] = arquivo['service'].replace(x,i)
    i = i +1

# %%
i =0
for x in arquivo["proto"].unique():
    arquivo ['proto'] = arquivo['proto'].replace(x,i)
    i = i +1

# %%
arquivo.head()
# Out:
#    id       dur  proto  service  state  spkts  dpkts  sbytes  dbytes  \
# 0   1  0.121478      0        0      0      6      4     258     172
# 1   2  0.649902      0        0      0     14     38     734   42014
# 2   3  1.623129      0        0      0      8     16     364   13186
# 3   4  1.681642      0        1      0     12     12     628     770
# 4   5  0.449454      0        0      0     10      6     534     268
#
#         rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  ct_ftp_cmd  \
# 0  74.087490  ...                 1               1             0           0
# 1  78.473372  ...                 1               2             0           0
# 2  14.170161  ...                 1               3             0           0
# 3  13.677108  ...                 1               3             1           1
# 4  33.373826  ...                 1              40             0           0
#
#    ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  attack_cat  \
# ...

# %%
#separa as variaveis
#y = coluna Species, o rotulo, setosa, versicolor, ou virginica
y = arquivo['attack_cat']

# x = todas as colunas menos a style, as caracteristicas, largura e comprimento da petula, etc..
x = arquivo.drop(['attack_cat','id','label'], axis=1)

# %%
from sklearn.model_selection import train_test_split
#criando o conjunto de dados de treino e test:
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size = 0.3)

# %%
from sklearn.ensemble import ExtraTreesClassifier
#criando modelos
modelo = ExtraTreesClassifier()
modelo.fit(x_treino,y_treino)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [74], line 4
#       2 #criando modelos
#       3 modelo = ExtraTreesClassifier()
# ----> 4 modelo.fit(x_treino,y_treino)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_forest.py:371, in BaseForest.fit(self, X, y, sample_weight)
#     364         raise ValueError(
#     365             "Sum of y is not strictly positive which "
#     366             "is necessary for Poisson regression."
#     367         )
#     369 self.n_outputs_ = y.shape[1]
# --> 371 y, expanded_class_weight = self._validate_y_class_weight(y)
#     373 if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#     374     y = np.ascontiguousarray(y, dtype=DOUBLE)
#
# ...
